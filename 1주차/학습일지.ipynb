# %%
## 학습일지
- pyenv(파이썬 버전 관리 도구), python, poetry(파이썬 패키지 관리 도구) 설치
- OpenAI API 키 발급
- LangSmith 추적 설정

### (준비) LangSmith
- 히스토리 (기록) > 레그 시스템 파이프라인의 복잡한 과정 > 트래킹
- 어느단계에서 문제가 발생하는지 파악 가능

### 0. 전역변수 설정
```shell
echo 'export PYENV_ROOT="$HOME/.pyenv"' >> ~/.zshrc
echo '[[ -d $PYENV_ROOT/bin ]] && export PATH="$PYENV_ROOT/bin:$PATH"' >> ~/.zshrc
echo 'eval "$(pyenv init -)"' >> ~/.zshrc
```

### 1. 기본 설정 `pyenv` 도구
> [참고자료](https://scshim.tistory.com/602) <br/>
> 파이썬의 버전을 선택해서 실행할 수 있게 해주는 도구

- 다양한 버전의 파이썬을 관리하는 도구 (여러 버전의 파이썬을 관리하는데 사용하는 도구)
- 올바른 버전의 파이썬을 사용하는 데 드는 시간 최소화, 프로젝트에 들이는 시간 최대화

#### 특징
1. 여러 파이썬 버전 관리
2. 프로젝트별 파이썬 버전 지정 `.python-version`
3. 가상 환경과 통합
4. 전역 및 로컬 버전 설정
    - 시스템 전체 또는 특정 디렉토리에 파이썬 버전 설정 가능
5. 플러그인 시스템


### 2. 파이썬 가상환경 `Virtual Environments`
- Anaconda
    - 가상환경을 관리해주는 소프트웨어

### 3. poetry
- 파이썬 패키지 관리 도구
- 해당 학습에서는 이미 의존성 문제 해결된 패키지들 제공해줌!


```shell
# poetry 설치
pip3 install poetry

# 다운로드 파일 이동
# 파이썬 가상환경 설정
poetry shell

# 파이썬 패키지 일괄 업데이트
poetry update
```

### (추가) 4. pip 명령어
- python3와 함께 제공되는 패키지 관리자
    - 기본적으로 포함되는 패키지

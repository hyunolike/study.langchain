# %% [markdown]
# ## 2주차 학습 목표 요약
# 1. LangChain 기본
# 2. 프롬프트
# 3. 모델
# 4. 문서 로더
# 5. 텍스트 분할
# 6. 임베딩
# 7. 벡터저장소
# 8. 검색기 (Retriever)
# 9. Retrieval Augmented Generation (RAG)
# 10. LangChain Expression Language (LCEL)
